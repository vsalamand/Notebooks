# %%
import pandas as pd
import numpy as np

# %%
family = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Mama_FAMILY_mailchimp_export.csv')
plus = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Mama_PLUS_mailchimp_members_export.csv')
budget =  pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/MAMA_BUDGET_mailchimp_members_export.csv')

# %%
budget
# Out:
#                    Email Address  First Name  Last Name  Address  \
# 0      kathleencambien@gmail.com         NaN        NaN      NaN
# 1           m.pennecot@gmail.com         NaN        NaN      NaN
# 2         margotmorin@outlook.fr         NaN        NaN      NaN
# 3   perrineblondel0611@gmail.com         NaN        NaN      NaN
# 4         portuguesa1@hotmail.fr         NaN        NaN      NaN
# 5    clairevandamme34@outlook.fr         NaN        NaN      NaN
# 6    claire.geronimo34@gmail.com         NaN        NaN      NaN
# 7            vittoria_08@live.it         NaN        NaN      NaN
# 8      amaning.aaron07@gmail.com         NaN        NaN      NaN
# 9          oceane.bbc@hotmail.fr         NaN        NaN      NaN
# 10      aaronamaning12@gmail.com         NaN        NaN      NaN
#
#     Phone Number  MEMBER_RATING           OPTIN_TIME  OPTIN_IP  \
# 0            NaN              2  2019-11-18 14:34:11       NaN
# ...
