# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import spacy
from spacy.lang.fr import French
from spacy.tokenizer import Tokenizer
from spacy.tokens import Doc
from spacy.vocab import Vocab
from spacy.matcher import Matcher
from spacy.matcher import PhraseMatcher
from textblob import TextBlob
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import re

# %%
measurements = {"g": ["gr.", "gr", "g", "g.", "gramme"], "kg": ["kg.", "kg", "kilogramme"], "mg": ["mg.", "mg", "miligramme"],
                "ml": ["ml.", "ml", "mililitre"], "cl": ["cl.", "cl", "centilitre"], "l": ["l.", "l", "litre"],
                "cuillère à soupe": ["c. à soupe", "cuillère à soupe", "cs", "cas", "càs", "c. à table", "cuillère à table"],
                "cuillère à café": ["c. à café", "cuillère à café", "cc", "cac", "càc", "c. à thé", "cuillère à thé"],
                "tasse": ["tasse"], "bol": ["bol"], "verre": ["verre"], "filet": ["filet"], "zeste": ["zeste"], "pièce": ["pièce"],
                "noisette": ["noisette"], "noix": ["noix"], "pincée": ["pincée"], "pointe":["pointe"], "poignée": ["poignée"],
                "feuille": ["feuille"], "branche": ["branche"], "gousse": ["gousse"], "tranche": ["tranche"], "cube": ["cube"],
                "boîte": ["boîte"], "barquette": ["barquette"], "pot": ["pot"], "bâtonnet": ["bâtonnet"], "boule": ["boule"],
                "rouleau": ["rouleau"], "p": ["p"]}

units = [item for sublist in measurements.values() for item in sublist]

quantities = { "½": 0.5, "1/2": 0.5, "1½": 1.5, "1 1/2": 0.5, "⅓": 0.33, "1/3": 0.33, "¼": 0.25, "1/5": 0.2, "¼": 0.25, "un demi": 0.5, "une demi": 0.5,"un et demi": 1.5,
              "tiers": 0.33, "quart": 0.25, "zero": 0, "deux": 2, "trois": 3, "quatre": 4,"cinq": 5, "six": 6, "sept": 7,
              "huit": 8, "neuf": 9, "dix": 10, "onze": 11, "douze": 12, "treize": 13, "quatorze": 14, "quinze": 15, "seize": 16,
              "dix-sept": 17, "dix-huit": 18, "dix-neuf": 19, "vingt": 20, "trente": 30, "quarante": 40, "cinquante": 50,
              "soixante": 60, "soixante-dix": 70, "quatre-vingt": 80, "quatre-vingt-dix": 90, "dizaine": 10, "une dizaine": 10,
              "douzaine": 12, "une douzaine": 12, "demi-douzaine": 6, "une demi-douzaine": 6, "vingtaine": 20, "une vingtaine": 20,
              "trentaine": 30, "quarantaine": 40, "cinquantaine": 50, "centaine": 100, "une centaine": 100, "cent": 100,
              "un": 1, "une": 1}

char_list = [i for i in "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZéèàâêïù▪️"]

# %%
web_product_data = pd.read_csv ('/Users/vincentsalamand/Downloads/products_leclerc.csv')
print(len(web_product_data))

data = pd.DataFrame()
data['quantity_match'] = ""
data['unit_match'] = ""
data['price_match'] = ""
data['price_per_unit_match'] = ""
data['is_promo'] = ""
data['offer'] = ""
data = pd.concat([data, web_product_data], axis=1)
data['shelter'] = ""
data['store'] = "Leclerc"
# Out:
# 8881

# %%
data['price_match'] = data.price.apply(lambda x: float(x.split()[0]))
data['price_per_unit_match'] = data.price_per_unit.apply(lambda x: float(x.split()[0]))
data.quantity_match = round(data.price_match / data.price_per_unit_match, 3)
#data['promo_price_per_unit_match'] = data.promo_price.apply(lambda x: float(re.sub("[^\d.]+", "", x)))

# Get names of indexes for which column price_per_unit_match is belo 0.03
missing_price_unit = data[data.price_per_unit_match < 0.03].index
# Delete these row indexes from dataFrame
data.drop(missing_price_unit , inplace=True)

# %%
# match description to find unit
nlp = French()

def convert_unit(value):
    results = []
    result = [unit for unit, item in measurements.items() if value in item]
    if len(result) > 0:
        return result[0]

measurement_matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
measurement_patterns = list(nlp.tokenizer.pipe(list(units)))
measurement_matcher.add("MEASUREMENT_PATTERN", None, *measurement_patterns)
tokenizer = Tokenizer(nlp.vocab)

measurement_parser = []
price_per_unit = list(nlp.pipe(data.price_per_unit))

for line in price_per_unit:
    line = tokenizer(re.sub('[0-9]', ' ', line.text))
    matches = measurement_matcher(line)
    elements = []
    if len(matches) > 0:
        for match_id, start, end in matches:
            span = line[start:end]
            elements.append(span.text.lower())
        measurement_parser.append(convert_unit(elements[0]))
    else:
        text_blob_object = TextBlob(line.text)
        singular_line = ' '.join(text_blob_object.words.singularize())
        matches = measurement_matcher(tokenizer(singular_line))
        if len(matches) > 0:
            for match_id, start, end in matches:
                span = tokenizer(singular_line)[start:end]
                elements.append(span.text.lower())
            measurement_parser.append(convert_unit(elements[0]))
        else:
            plural_line = ' '.join(text_blob_object.words.pluralize())
            matches = measurement_matcher(tokenizer(plural_line))
            if len(matches) > 0:
                for match_id, start, end in matches:
                    span = tokenizer(plural_line)[start:end]
                    elements.append(span.text.lower())
                measurement_parser.append(convert_unit(elements[0]))
            else:
                 measurement_parser.append("")

data['unit_match'] = measurement_parser

# %%
data.shelter_main.unique()
# Out:
# array(['Viandes Poissons', 'Fruits Légumes', 'Pains Pâtisseries', 'Frais',
#        'Surgelés', 'Epicerie salée', 'Epicerie sucrée', 'Boissons'],
#       dtype=object)

# %%
# find if product is in promo
# rename piece unit
# get shelter list

for index, product in data.iterrows():
    if data.loc[index].offer_description == data.loc[index].price:
        data.loc[index,'is_promo'] = False
        data.loc[index,'offer_description'] = np.nan
    else:
        data.loc[index,'is_promo'] = True
    if data.loc[index].unit_match == "p":
        data.loc[index,'unit_match'] = "pièce"
    if data.loc[index].is_frozen == "f":
        data.loc[index,'is_frozen'] = False   
    if data.loc[index].is_frozen == "t":
        data.loc[index,'is_frozen'] = True         
    shelter = []
    shelter.append(data.loc[index].shelter_main)
    shelter.append(data.loc[index].shelter_parent)
    shelter.append(data.loc[index].shelter_child)
    data.at[index,'shelter'] = shelter

# %%
# Add ean & is_frozen column based on db_products + clean_description to avoid duplicate process later on
db_products = pd.read_csv('/Users/vincentsalamand/Downloads/product_export.csv')
db_store_items = pd.read_csv('/Users/vincentsalamand/Downloads/store_items_export.csv')

db_products_ean = db_products[['id', 'ean', 'is_frozen']]
db_store_items_ean = db_store_items.merge(db_products_ean, left_on=['product_id'], right_on=['id'])
db_store_items_ean = db_store_items_ean[['clean_name', 'store_product_id', 'ean', 'is_frozen']]

data = pd.merge(data, db_store_items_ean.rename(columns={'store_product_id':'product_id'}), on='product_id',  how='left')

# %%
db_store_items
# Out:
#         id  product_id  store_id  store_product_id  \
# 0        5        1712         1             18218
# 1        4        1711         1             20982
# 2       14        1721         1             20858
# 3        6        1713         1             32843
# 4        7        1714         1             46231
# 5        8        1715         1             84763
# 6       16        1723         1             18219
# 7       10        1717         1             46230
# 8       11        1718         1             78967
# 9       12        1719         1             29285
# 10      13        1720         1             20859
# 11      15        1722         1             55805
# 12      17        1724         1             84355
# 13      18        1725         1             35295
# 14      19        1726         1             31219
# 15       3        1710         1             55810
# 16       9        1716         1             84353
# 17      21        1728         1             54134
# 18      34        1741         1             41359
# 19      25        1732         1              7303
# 20      29        1736         1             26246
# 21      26        1733         1             54133
# 22      28        1735         1             27053
# 23      22        1729         1             48504
# 24      30        1737         1             26672
# 25      31        1738         1             27052
# 26      32        1739         1             27494
# 27      33        1740         1             16824
# 28      24        1731         1             85455
# 29      35        1742         1             26250
# ...    ...         ...       ...               ...
# 8477  8485       10192         1             50131
# 8478  8486       10193         1             24836
# 8479  8020        9727         1             36418
# 8480  8487       10194         1             48801
# 8481  8488       10195         1             51935
# 8482  8029        9736         1             19209
# 8483  6231        7938         1             36704
# 8484  8489       10196         1              8674
# 8485  8490       10197         1             26383
# 8486  8491       10198         1             26361
# 8487  8492       10199         1             48844
# 8488  8493       10200         1             63543
# 8489  8494       10201         1              2524
# 8490  8495       10202         1              8647
# 8491  8496       10203         1             80110
# 8492  8497       10204         1             33399
# 8493  8059        9766         1             32550
# 8494  6439        8146         1             64816
# 8495  6542        8249         1             25615
# 8496  6581        8288         1             63798
# 8497  8498       10205         1             20069
# 8498  8499       10206         1             42572
# 8499  8500       10207         1             59028
# 8500  8501       10208         1             48854
# 8501  8502       10209         1            108743
# 8502  7011        8718         1             47726
# 8503  8503       10210         1             22033
# 8504  8504       10211         1             28576
# 8505  8505       10212         1             86743
# 8506  8506       10213         1             44330
#
#                                        clean_name  \
# 0                                     chipolata 5
# 1                            chipolata la rouge 3
# 2                          saucisse de Toulouse 5
# 3                                     chipolata 3
# 4                               chipolata en et 3
# 5                                     chipolata 3
# 6                                       merguez 3
# 7                     saucisse en et aux herbes 3
# 8                       saucisse la de Toulouse 3
# 9             saucisse de Toulouse la rouge île 5
# 10                           saucisse de Toulouse
# 11                                    merguez 5 5
# 12                         merguez au naturel gin
# 13                        mini île en et nature 3
# 14                               mini île en et 3
# 15                         saucisse chipolata 5 5
# 16                           chipolata au naturel
# 17                        viande vin au filet île
# 18                                   bavette au 3
# 19                        viande vin au filet île
# 20                  viande vin la entrecôte île 3
# 21                       viande vin entrecôte île
# 22                     viande vin entrecôte île 3
# 23                                       au filet
# 24             viande vin entrecôte épaisse île 3
# 25                       viande vin entrecôte île
# 26                            viande vin côte île
# 27                      bavette viande vin au île
# 28                                au filet viande
# 29                      viande vin bavette au île
# ...                                           ...
# 8478  Compote Pom'Potes Materne Pomme Mirabelle - 4x90g   1.77
# 8479  Dessert fruitier Douceur Verger Pomme poire - ...   1.07
# 8480  Compotes Nos Régions ont  du talent - Pommes -...   2.24
# 8481     Goûter Récré O'lé  Mont Blanc Vanille - 12x85g   4.82
# 8482          Sucre de canne Bio Daddy En poudre - 750g   2.13
# 8483  Sucre en morceaux Daddy Demi-morceaux rond - 750g   0.81
# 8484                           Sucre Gélifiant Téva 1kg   1.33
# 8485  Levure chimique Vahiné Moelleux prolongé x5 - ...   0.73
# 8486  Levure super active Vahiné Spécial pain sachet...   1.15
# 8487  Préparation gâteau Nestlé Moelleux chocolat - ...   3.62
# 8488  Décor pour gateaux Vahiné Crayon patissier bla...   1.84
# 8489            Amandes Couleurs Vives En poudre - 125g   2.09
# 8490      Gélatine alimentaire Tablier 9 feuilles - 17g   1.02
# 8491      Spray de cuisson La Patelière Cuitout - 125ml   2.84
# 8492            Pâte d'amande 40% Vahiné Tricolore 150g   2.11
# 8493                Thé glacé Lipton Ice Tea Pêche - 2L   1.65
# 8494     Boisson Lipton Ice Tea Pêche zero sucre - 1.5L   1.43
# 8495                      Pulco Agrumes A diluer - 70cl   2.59
# 8496               Soda Schweppes Agrumes Zero - 6x33cl   2.94
# 8497          Eau gazeuse Salvetat aromatisée Citron -    0.77
# 8498                 Pur jus de grenade Jardin Bio 50cl   4.50
# 8499  Boisson Détox Jardin Bio' Citron Thé Vert Ging...   3.76
# 8500  Jus de carotte Le jardin Bio Origine France - ...   2.60
# 8501  Boisson végétale Santal Amande saveur canelle ...   2.30
# 8502             Bière Red Desperados 5.9%vol. - 3x33cl   4.16
# 8503          Gin Brighton's London Dry 37.5%vol - 70cl   9.15
# 8504               Liqueur Passoa Passion 15%vol - 70cl   7.75
# 8505  Vin blanc Vieux Carion Colombard Sauvignon IGP...   2.45
# 8506     Vin blanc Roche Mazet  Chardonnay AOC - BIB 3L  10.20
#
#       price_per_unit is_promo  promo_price_per_unit  \
# 0               9.30        f                  3.07
# 1              10.76        f                  3.55
# 2               7.06        f                  3.53
# 3               9.39        f                  3.10
# 4               8.48        f                  2.80
# 5              11.18        f                  3.69
# 6               9.30        f                  3.07
# 7               6.97        f                  2.30
# 8               1.80        f                  5.41
# 9              10.60        f                  5.30
# 10              7.37        f                  7.37
# 11             14.51        f                  3.99
# 12              8.60        f                  8.60
# 13              9.34        f                  2.99
# 14              9.34        f                  2.99
# 15             14.76        f                  4.06
# 16              6.69        f                  8.03
# 17             30.31        f                  4.85
# 18             28.65        f                  7.45
# 19             21.81        f                  3.49
# 20             27.22        f                  9.80
# 21             29.12        f                  4.95
# 22             23.41        f                  7.96
# 23             24.95        f                  4.99
# 24             23.30        f                  6.99
# 25             23.18        f                  3.94
# 26             21.98        f                 13.19
# 27             19.79        f                  5.54
# 28             27.70        f                  5.54
# 29             23.71        f                  6.64
# ...              ...      ...                   ...
# 8477            3.81        f                  6.85
# 8478            4.92        f                  1.77
# 8479            2.97        f                  1.07
# 8480            3.80        f                  2.24
# 8481            4.73        f                  4.82
# 8482            2.84        f                  2.13
# 8483            1.08        f                  0.81
# 8484            1.33        f                  1.33
# 8485           15.21        f                  0.73
# 8486            6.85        f                  1.15
# 8487           10.52        f                  3.62
# 8488           73.60        f                  1.84
# 8489           16.72        f                  2.09
# 8490           60.00        f                  1.02
# 8491           22.72        f                  2.84
# 8492           14.07        f                  2.11
# 8493            0.83        f                  1.65
# 8494            0.95        f                  1.43
# 8495            3.70        f                  2.59
# 8496            1.48        f                  2.94
# 8497            0.62        f                  0.77
# 8498            9.00        f                  4.50
# 8499            7.52        f                  3.76
# 8500            3.47        f                  2.60
# 8501            2.30        f                  2.30
# 8502            4.20        f                  4.16
# 8503           13.07        f                  9.15
# 8504           11.07        f                  7.75
# 8505            3.27        f                  2.45
# 8506            3.40        f                 10.20
#
#                                                     url  \
# 0     https://fd4-courses.leclercdrive.fr/magasin-12...
# 1     https://fd4-courses.leclercdrive.fr/magasin-12...
# 2     https://fd4-courses.leclercdrive.fr/magasin-12...
# 3     https://fd4-courses.leclercdrive.fr/magasin-12...
# 4     https://fd4-courses.leclercdrive.fr/magasin-12...
# 5     https://fd4-courses.leclercdrive.fr/magasin-12...
# 6     https://fd4-courses.leclercdrive.fr/magasin-12...
# 7     https://fd4-courses.leclercdrive.fr/magasin-12...
# 8     https://fd4-courses.leclercdrive.fr/magasin-12...
# 9     https://fd4-courses.leclercdrive.fr/magasin-12...
# 10    https://fd4-courses.leclercdrive.fr/magasin-12...
# 11    https://fd4-courses.leclercdrive.fr/magasin-12...
# 12    https://fd4-courses.leclercdrive.fr/magasin-12...
# 13    https://fd4-courses.leclercdrive.fr/magasin-12...
# 14    https://fd4-courses.leclercdrive.fr/magasin-12...
# 15    https://fd4-courses.leclercdrive.fr/magasin-12...
# 16    https://fd4-courses.leclercdrive.fr/magasin-12...
# 17    https://fd4-courses.leclercdrive.fr/magasin-12...
# 18    https://fd4-courses.leclercdrive.fr/magasin-12...
# 19    https://fd4-courses.leclercdrive.fr/magasin-12...
# 20    https://fd4-courses.leclercdrive.fr/magasin-12...
# 21    https://fd4-courses.leclercdrive.fr/magasin-12...
# 22    https://fd4-courses.leclercdrive.fr/magasin-12...
# 23    https://fd4-courses.leclercdrive.fr/magasin-12...
# 24    https://fd4-courses.leclercdrive.fr/magasin-12...
# 25    https://fd4-courses.leclercdrive.fr/magasin-12...
# 26    https://fd4-courses.leclercdrive.fr/magasin-12...
# 27    https://fd4-courses.leclercdrive.fr/magasin-12...
# 28    https://fd4-courses.leclercdrive.fr/magasin-12...
# 29    https://fd4-courses.leclercdrive.fr/magasin-12...
# ...                                                 ...
# 8477  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8478  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8479  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8480  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8481  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8482  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8483  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8484  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8485  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8486  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8487  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8488  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8489  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8490  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8491  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8492  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8493  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8494  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8495  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8496  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8497  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8498  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8499  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8500  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8501  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8502  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8503  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8504  https://fd4-courses.leclercdrive.fr/magasin-12...
# 8505  https://fd4-courses.leclercdrive.fr/magasin-12...
# 
{"Epicerie sucrée","Desserts, Sucres et Farine...
# 8492  {"Epicerie sucrée","Desserts, Sucres et Farine...
# 8493  {Boissons,"Sodas et Boissons aux fruits","Thés...
# 8494  {Boissons,"Sodas et Boissons aux fruits","Thés...
# 8495  {Boissons,"Sodas et Boissons aux fruits","Siro...
# 8496  {Boissons,"Sodas et Boissons aux fruits","Bois...
# 8497      {Boissons,"Eaux et Laits","Eaux aromatisées"}
# 8498  {Boissons,"Jus de fruits et légumes","Jus de f...
# 8499  {Boissons,"Jus de fruits et légumes","Autres j...
# 8500  {Boissons,"Jus de fruits et légumes","Jus de l...
# 8501  {Boissons,"Jus de fruits et légumes","Boissons...
# 8502  {Boissons,"Bières et Cidres","Bières blanches ...
# 8503  {Boissons,"Alcools et Apéritifs","Vodka, Gin e...
# 8504  {Boissons,"Alcools et Apéritifs","Rhums, cockt...
# 8505                      {Boissons,Vins,"Vins blancs"}
# 8506                      {Boissons,Vins,"Vins blancs"}
#
# [8507 rows x 16 columns]

# %%
from selenium import webdriver
import requests
from bs4 import BeautifulSoup, CData
import html
from multiprocessing.dummy import Pool 

driver = webdriver.Chrome("/Applications/chromedriver")

def scrape_leclerc_product_pages(url):
    if pd.isna(data.iloc[index].ean):
        driver.get(url)
        soup = BeautifulSoup(driver.page_source)
        product_info = []
        page = html.unescape(soup.text)
        page = page[(page.find('objProduit')-2):(page.find('objContenu')-2)]
        for line in page.split(","):
            if "fSurgele" in line:
                data.loc[data.url == url].is_frozen = line[11:]
            if "sCodeEAN" in line:
                data.loc[data.url == url].ean = line[12:-1]


p = Pool(20)
p.map(scrape_leclerc_product_pages, data.url)
p.terminate()
p.join()

# %%
data
# Out:
#       quantity_match unit_match  price_match  price_per_unit_match  is_promo  \
# 0              0.160         kg         4.46                 27.88     False
# 1              0.200         kg         4.99                 24.95     False
# 2              0.160         kg         3.35                 20.94     False
# 3              0.200         kg         5.54                 27.70     False
# 4              0.320         kg         6.34                 19.81     False
# 5              0.160         kg         3.49                 21.81     False
# 6              0.170         kg         4.95                 29.12     False
# 7              0.340         kg        10.56                 31.06     False
# 8              0.340         kg         7.96                 23.41     False
# 9              0.360         kg         9.80                 27.22     False
# 10             0.300         kg         6.99                 23.30     False
# 11             0.170         kg         3.94                 23.18     False
# 12             0.280         kg         5.54                 19.79     False
# 13             0.260         kg         7.45                 28.65     False
# 14             0.280         kg         6.64                 23.71     False
# 15             0.280         kg        11.50                 41.07     False
# 16             0.280         kg         5.66                 20.21     False
# 17             0.240         kg         4.99                 20.79     False
# 18             0.260         kg         5.40                 20.77     False
# 19             0.300         kg         5.89                 19.63     False
# 20             0.160         kg         3.99                 24.94     False
# 21             0.280         kg         3.83                 13.68     False
# 22             0.140         kg         2.92                 20.86     False
# 23             0.280         kg         5.17                 18.46     False
# 24             0.520         kg         9.00                 17.31     False
# 25             0.520         kg         8.00                 15.38     False
# 26             0.280         kg         5.28                 18.86     False
# 27             0.130         kg         2.79                 21.46     False
# 28             0.280         kg         5.49                 19.61     False
# 29             0.230         kg         4.90                 21.30     False
# ...              ...        ...          ...                   ...       ...
# 8841           0.750          l        17.75                 23.67     False
# 8842           0.750          l        24.80                 33.07     False
# 8843           0.750          l         4.34                  5.79     False
# 8844           0.750          l         4.34                  5.79     False
# 8845           0.750          l         1.29                  1.72     False
# 8846           0.750          l         4.80                  6.40     False
# 8847           0.751          l         2.32                  3.09     False
# 8848           0.750          l         4.05                  5.40     False
# 8849           0.749          l         2.33                  3.11     False
# 8850           0.749          l         2.87                  3.83     False
# 8851           0.749          l         2.87                  3.83     False
# 8852           0.750          l         2.28                  3.04     False
# 8853           0.750          l         5.89                  7.85     False
# 8854           0.750          l         4.45                  5.93     False
# 8855           0.749          l         2.33                  3.11     False
# 8856           0.750          l         5.20                  6.93     False
# 8857           0.750          l         5.85                  7.80     False
# 8858           0.750          l         4.80                  6.40     False
# 8859           0.749          l         2.33                  3.11     False
# 8860           0.750          l         2.28                  3.04     False
# 8861           0.750          l         4.30                  5.73     False
# 8862           0.750          l         5.83                  7.77     False
# 8863           0.750          l         5.79                  7.72     False
# 8864           0.750          l         5.47                  7.29     False
# 8865           0.750          l         6.65                  8.87     False
# 8866           0.750          l         6.49                  8.65     False
# 8867           0.750          l         5.50                  7.33     False
# 8868           0.750          l         5.04                  6.72     False
# 8869           0.751          l         2.65                  3.53     False
# 8870           0.751          l         2.74                  3.65     False
#
#      offer           brand                     description1  \
# 0      NaN     Bio Village     Viande bovine Fr Bio Village
# 1      NaN          Charal            Faux filet *** Charal
# 2      NaN          Férial        Viande bovine  Férial 1x
# 3      NaN             NaN      Faux filet viande Limousine
# 4      NaN             NaN  Viande bovine 2x faux filet ***
# 5      NaN             NaN  Viande bovine 1x faux filet ***
# 6      NaN             NaN   Viande bovine 1x entrecôte ***
# 7      NaN             NaN                Viande bovine Bio
# 8      NaN             NaN   Viande bovine 2x entrecôte ***
# 9      NaN             NaN         Viande bovine Charolaise
# 10     NaN             NaN    Viande bovine 1x entrecôte***
# 11     NaN             NaN   Viande bovine 1x entrecôte ***
# 12     NaN          Férial    Bavette Viande bovine Férial
# 13     NaN          Charal      Bavette d'Aloyau *** Charal
# 14     NaN             NaN         Viande bovine 2x bavette
# 15     NaN          Charal             Tournedos *** Charal
# 16     NaN             NaN        Viande bovine 2x pavé ***
# 17     NaN             NaN         Viande bovine Bio vilage
# 18     NaN             NaN     Viande bovine Bio 2x steak**
# 19     NaN          Charal  Viande bovine Charal3x steak***
# 20     NaN          Charal  Viande Bovine Française Charal:
# 21     NaN          Férial             Viande bovine Férial
# 22     NaN             NaN           Steak viande Limousine
# 23     NaN             NaN           Seak viande limousine
# 24     NaN             NaN        Viande bovine 4x steak **
# 25     NaN             NaN          Viande Bovine 4x steak*
# 26     NaN             NaN         Viande bovine Charolaise
# 27     NaN          Charal                 Steak *** Charal
# 28     NaN             NaN        Viande bovine 2x pavé ***
# 29     NaN          Charal            Viande Bovine Charal
# ...    ...             ...                              ...
# 8841   NaN      Pol Carson        Champagne rosé Pol Carson
# 8842   NaN  Canard Duchêne         Champagne Canard Duchêne
# 8843   NaN             NaN        Vin mousseux blanc Kriter
# 8844   NaN             NaN              Vin mousseux Kriter
# 8845   NaN             NaN                Vin mousseux brut
# 8846   NaN             NaN    Vin mousseux J.P Chenet Blanc
# 8847   NaN             NaN            Vin mousseux Paul Bur
# 8848   NaN  Charles Volner      Vin mousseux Charles Volner
# 8849   NaN   Diane d'Arria      Vin mousseux Diane d'Arriac
# 8850   NaN             NaN         Vin blanc mousseux Bazer
# 8851   NaN          Blazer        Vin blanc mousseux Blazer
# 8852   NaN        Muscador      Vin mousseux blanc Muscador
# 8853   NaN             NaN             Vin mousseux Vouvray
# 8854   NaN             NaN       Saumur brut Les caractères
# 8855   NaN   Diane d'Arria    Blanc de blancs Diane d'Arria
# 8856   NaN             NaN                 Clairette de Die
# 8857   NaN             NaN       Clairette de Die Jaillance
# 8858   NaN             NaN     Vin mousseux J.P Chenet Rosé
# 8859   NaN   Diane d'Arria       Vin mousseux Diane d'Arria
# 8860   NaN        Muscador       Vin mousseux rosé Muscador
# 8861   NaN             NaN              Vin mousseux Kriter
# 8862   NaN             NaN      Crémant Bourgogne A.Barrier
# 8863   NaN         Rebmann         Crémant d'Alsace Rebmann
# 8864   NaN             NaN  Crémant de Loire Les Caractères
# 8865   NaN             NaN              Crémant de Bordeaux
# 8866   NaN             NaN  Vin blanc italien Maison Malesa
# 8867   NaN             NaN   Pétillants Prosecco Riccadonna
# 8868   NaN             NaN        Vin mousseux Villa Veroni
# 8869   NaN             NaN    Boisson sans alcool D'Artigny
# 8870   NaN        Festalie   Pétillant Festalie sans alcool
#
#                          description2  \
# 0                   Faux filet - 160g
# 1                           x1 - 200g
# 2     faux filet *** à griller - 160g
# 3                                200g
# 4                    à griller - 320g
# 5                    à griller - 160g
# 6                à griller Bio - 170g
# 7             Entrecôte *** x2 - 340g
# 8                    à griller - 340g
# 9     2x entrecôte *** à griller 360g
# 10           Epaisse à griller - 300g
# 11                   à griller - 170g
# 12      Aloyau ***à griller x2 - 280g
# 13                             2x130g
# 14        Aloyau *** à griller - 280g
# 15                             2x140g
# 16         tournedos à griller - 280g
# 17            Vbf - steak*** - 2x120g
# 18                   A griller - 260g
# 19                   à griller - 300g
# 20             Mini Bifteck x2 - 160g
# 21          steak ** à griller - 280g
# 22                               140g
# 23                            2x140 g
# 24                   à griller - 520g
# 25                   à griller - 520g
# 26     2x steak  *** à griller - 280g
# 27                               130g
# 28                   à griller - 280g
# 29       Carpaccio au parmesan - 230g
# ...                               ...
# 8841                      Brut - 75cl
# 8842             Rosé - 12%vol - 75cl
# 8843                  Demi-sec - 75cl
# 8844                      Brut - 75cl
# 8845                             75cl
# 8846                    11%vol - 75cl
# 8847                  Demi-sec - 75cl
# 8848        Demi-sec - 11%vol. - 75cl
# 8849  Blanc de blancs Demi sec - 75cl
# 8850      1/2 sec Blanc de Blanc 75cl
# 8851              Blanc de Blanc 75cl
# 8852              Doux 11.5%vol. 75cl
# 8853                  Brut AOC - 75cl
# 8854                         AOC 75cl
# 8855                        Brut 75cl
# 8856           Rives & Terrasses 75cl
# 8857                 Tradition - 75cl
# 8858                    11%vol - 75cl
# 26                          viande vin la steak île  3266110093562     False
# 27                                          steak 3  3181238941444     False
# 28                              viande vin pavé île  3266110094347     False
# 29               viande vin carpaccio au parmesan 3  3181232180504     False
# ...                                             ...            ...       ...
# 8841                   champagne rosé Napolitaine 5  3564700283738     False
# 8842                  champagne canard chêne rosé 5  3113934004192     False
# 8843                       vin mousseux blanc sec 5  3058080068226     False
# 8844                                 vin mousseux 5  3058080068219     False
# 8845                                 vin mousseux 5  3450970024990     False
# 8846                        vin mousseux et blanc 5  3500610085338     False
# 8847             vin mousseux au cheeseburger sec 5  3245593000014     False
# 8848                         vin mousseux île sec 5  3438931010428     False
# 8849  vin mousseux di blanc de blanc demi-sel sec 5  3564700030707     False
# 8850        vin blanc mousseux sec blanc de blanc 5  3564700028698     False
# 8851         vin blanc mousseux la blanc de blanc 5  3564700028674     False
# 8852                    vin mousseux blanc doux 5 5  3438931000580     False
# 8853                                 vin mousseux 5  3564700334379     False
# 8854                                  au coleslaw 5  3564700527122     False
# 8855                            blanc de blanc di 5  3564700030684     False
# 8856                                 la de di ras 5  3564700394205     False
# 8857                        la de di la tradition 5  3416140120572     False
# 8858                         vin mousseux et rosé 5  3500610093708     False
# 8859                         vin mousseux di rosé 5  3564700704783     False
# 8860                     vin mousseux rosé doux 5 5  3438931000597     False
# 8861                            vin mousseux rosé 5  3058080079727     False
# 8862                                  crémant bar 5  3564700332207     False
# 8863                                      crémant 5  3564700063729     False
# 8864                          crémant de coleslaw 5  3564700631775     False
# 8865                            crémant de au île 5  3175529644022     False
# 8866             vin blanc l'italienne île sec la 5  3180284905257     False
# 8867                          pétillant sec extra 5  8000368202605     False
# 8868            vin mousseux la pastis 5 volaille 5  3180280403450     False
# 8869                              boisson rôti la 5  3138670640039     False
# 8870                              pétillant pêche 5  3564700504062     False
#
# [7616 rows x 25 columns]

# %%
#data.ean.fillna(0, inplace=True)
data.ean = data.ean.astype(int)
data = data.drop_duplicates(subset='ean', keep='first')

# %%
export_csv = data.to_csv (r'/Users/vincentsalamand/Downloads/leclerc_catalog.csv', index = None, header=True)

# %%
removed_items = db_store_items[~db_store_items.store_product_id.isin(data.product_id)]
len(removed_items)
#new_items = data[~data.product_id.isin(db_store_items.store_product_id)]
#len(new_items)
remaining_items = data[data.product_id.isin(db_store_items.store_product_id)]
len(remaining_items)
#df1[df1.product_id == 104789]
# Out:
# 7537

# %%
db_foods = pd.read_csv('/Users/vincentsalamand/Downloads/food_export.csv')

food_vocab = [food.split() for food in db_foods.name]
food_vocab_uniq = set([item for sublist in food_vocab for item in sublist])
food_vocab_uniq

for index, product in data.iterrows():
    # get clean name only if not already there
    if pd.isna(data.iloc[index].clean_name):
        description = ''.join(product.description)    
        clean_description = []
        for word in description.lower().split():
            ratio = process.extractOne(word, food_vocab_uniq)
            if ratio[1] > 88:
                clean_description.append(ratio[0])
        data.loc[index,'clean_name']  = ' '.join(clean_description)
# Out:
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ':']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '%']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '&']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ':']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '&']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '&']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
