# %%
import requests

from time import sleep
import pandas as pd 
import numpy as np
import re
import tldextract
import html
import scrape_schema_recipe
from ast import literal_eval
from html import unescape

# %%
amandinebasilic = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/amandinebasilic.csv')
cahierdegourmandises = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/cahierdegourmandises.csv')
clemfoodie = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/clemfoodie.csv')
cuisineaddict = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/cuisine-addict.csv')
cuisineculinaire = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/cuisineculinaire.csv')
cuisinemoiunmouton = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/cuisinemoiunmouton.csv')
deliacious = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/deliacious.csv')
delizioso = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/delizioso.csv')
emiliemurmure = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/emiliemurmure.csv')
fourneauxetfourchettes = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/fourneauxetfourchettes.csv')
freethepickle = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/freethepickle.csv')
mahealthytendency = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/mahealthytendency.csv')
marciatack = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/marciatack.csv')
mesbrouillonsdecuisine = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/mesbrouillonsdecuisine.csv')
papillesetpupilles = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/papillesetpupilles.csv')
tangerinezest = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/tangerinezest.csv')
undejeunerdesoleil = pd.read_csv ('/Users/vincentsalamand/Documents/Clubmama/Recipes/undejeunerdesoleil.csv')


recipes = [amandinebasilic, cahierdegourmandises, clemfoodie, cuisineaddict, cuisineculinaire, cuisinemoiunmouton,
            deliacious, delizioso, emiliemurmure, fourneauxetfourchettes, freethepickle, mahealthytendency,
           marciatack, mesbrouillonsdecuisine, papillesetpupilles, tangerinezest, undejeunerdesoleil]

# %%
recipe_data = pd.concat(recipes, ignore_index=True, sort=False)

# %%
recipe_data
# Out:
#                                                     url  \
# 0       https://amandebasilic.com/chai-massala-bhoutan/
# 1     https://amandebasilic.com/chocolat-chaud-noel-...
# 2     https://amandebasilic.com/citronnade-menthe-me...
# 3              https://amandebasilic.com/creme-de-mure/
# 4     https://amandebasilic.com/detox-water-lilas-mu...
# ...                                                 ...
# 7855  https://www.undejeunerdesoleil.com/2018/12/coc...
# 7856  https://www.undejeunerdesoleil.com/2018/09/gin...
# 7857  https://www.undejeunerdesoleil.com/2018/09/bel...
# 7858  https://www.undejeunerdesoleil.com/2018/02/iri...
# 7859  https://www.undejeunerdesoleil.com/2017/06/bie...
#
#                        cookTime                   prepTime  \
# 0                    20 minutes                  5 minutes
# 1                    10 minutes                 10 minutes
# 2                     5 minutes                 10 minutes
# 3                           NaN                  5 minutes
# 4                           NaN                 10 minutes
# ...                         ...                        ...
# 7855                        NaN  0 days 00:10:00.000000000
# 7856                        NaN  0 days 00:05:00.000000000
# 7857                        NaN  0 days 00:10:00.000000000
# 7858  0 days 00:05:00.000000000  0 days 00:10:00.000000000
# 7859                        NaN  0 days 00:15:00.000000000
#
#                                          name  \
# 0                                Chaï massala
# 1                      Chocolat chaud de Noël
# 2                   Citronnade menthe mélisse
# 3                                  Clementine
# 4             Detox water aux fleurs de lilas
# ...                                       ...
# 7855             Cocktail Balalaïka ou Troïka
# 7856                                Gin Tonic
# 7857                         Bellini cocktail
# 7858                             Irish coffee
# 7859  Bière de gingembre maison (ginger beer)
#
#                                                   image  \
# 0     ['https://amandebasilic.com/wp-content/uploads...
# 1     ['https://amandebasilic.com/wp-content/uploads...
# 2     ['https://amandebasilic.com/wp-content/uploads...
# 3     ['https://amandebasilic.com/wp-content/uploads...
# 4     ['https://amandebasilic.com/wp-content/uploads...
# ...                                                 ...
# 7855  ['https://www.undejeunerdesoleil.com/wp-conten...
# 7856  ['https://www.undejeunerdesoleil.com/wp-conten...
# 7857  ['https://www.undejeunerdesoleil.com/wp-conten...
# 7858  ['https://www.undejeunerdesoleil.com/wp-conten...
# 7859  ['https://www.undejeunerdesoleil.com/wp-conten...
#
#                                        recipeIngredient  \
# 0     ['4 cuillères à thé de thé noir', '6 gousses d...
# 1     ['250 g de chocolat à 70% de cacao', '2 fèves ...
# 2     ['1 litre d’eau', '4 citrons jaunes bio', '20 ...
# 3     ['1 kg de mûres', '1 bouteille de vin rouge', ...
# 4     ['1 litre d’eau de source', '1 belle grappe de...
# ...                                                 ...
# 7855  ['12 cl vodka', '8 cl triple sec (type Grand M...
# 7856  ['16 cl gin', '8 cl jus de citron (facultatif)...
# 7857  ['160 g pêche (blanche (pulpe) ou de nectarine...
# 7858  ['16 cl whisky (Irish)', '32 cl café (chaud)',...
# 7859  ['1 l eau minérale', '100 g gingembre  (frais ...
#
#                                      recipeInstructions          recipeYield  \
# 0     ['Tout d’abord, faire une décoction d’épices p...             4 tasses
# 1     ['Tout d’abord, préparer l’infusion de fèves t...          4 personnes
# 2     ['Dans une casserole, faire chauffer à feu dou...      1 litre environ
# 3     ['Mettre à macérer les mûres lavées et écrasée...                  NaN
# 4     ['Tout d’abord, laver soigneusement les fleurs...  4 personnes (1 pot)
# ...                                                 ...                  ...
# 7855  ["Verser le sucre dans une petite assiette. Mo...          4 personnes
# 7856  ['Remplir la moitié des verres avec des glaçon...          4 personnes
# 7857  ['Mettre les verres au frais 5 minutes. Pendan...          4 personnes
# 7858  ["Préparer la crème fouettée : dans un bol, fo...          4 personnes
# 7859  ['Couper en tout petits dés le gingembre, le h...     4 personnes (1l)
#
#                  author                  totalTime              datePublished
# 0     Amande et Basilic                        NaN                        NaN
# 1     Amande et Basilic                        NaN                        NaN
# 2     Amande et Basilic                        NaN                        NaN
# 3     Amande et Basilic                 10 minutes                        NaN
# 4     Amande et Basilic                 10 minutes                        NaN
# ...                 ...                        ...                        ...
# 7855       Edda Onorato                        NaN  2018-12-31 08:00:23+00:00
# 7856       Edda Onorato  0 days 00:05:00.000000000  2018-09-29 09:00:26+00:00
# 7857               Edda  0 days 00:10:00.000000000  2018-09-08 09:00:22+00:00
# 7858       Edda Onorato                        NaN  2018-02-26 09:00:37+00:00
# 7859       Edda Onorato                        NaN  2017-06-19 07:00:00+00:00
#
# [7860 rows x 11 columns]

# %%
#recipe_data[recipe_data['name'].str.lower().str.contains("pizza", na=False) ]
#recipe_data[recipe_data['name'].str.lower().str.contains("burger", na=False) ]
#recipe_data[recipe_data['name'].str.lower().str.contains("dwich", na=False) ]
recipe_data[recipe_data['name'].str.lower().str.contains("dessert", na=False) ]
# Out:
#                                                     url  \
# 2047  http://cuisinemoiunmouton.com/tarte-framboise-...
# 2233  http://cuisinemoiunmouton.com/tarte-framboise-...
# 2356  https://deliacious.com/2019/02/cremes-noix-de-...
# 4807  https://www.marciatack.fr/recette-trifle-au-ki...
# 6923  https://tangerinezest.com/creme-dessert-chocol...
# 7043  https://tangerinezest.com/creme-dessert-a-la-p...
#
#                        cookTime                   prepTime  \
# 2047                        NaN                    0:45:00
# 2233                        NaN                    0:45:00
# 2356  0 days 00:05:00.000000000  0 days 00:10:00.000000000
# 4807                        NaN  0 days 00:05:00.000000000
# 6923  0 days 00:40:00.000000000  0 days 00:10:00.000000000
# 7043                        NaN                        NaN
#
#                                                    name  \
# 2047  Tarte framboise pistache pour un dessert gourm...
# 2233  Tarte framboise pistache pour un dessert gourm...
# 2356             Crèmes dessert noix de coco et vanille
# 4807              Trifle au kiwi, un dessert tout léger
# 6923                     Crème dessert chocolat et café
# 7043                        Crème dessert à la pistache
#
#                                                   image  \
# 2047  ['http://cuisinemoiunmouton.com/wp-content/upl...
# 2233  ['http://cuisinemoiunmouton.com/wp-content/upl...
# 2356  ['https://deliacious.com/wp-content/uploads/20...
# 4807  ['https://www.marciatack.fr/wp-content/uploads...
# 6923  ['https://tangerinezest.com/wp-content/uploads...
# 7043  ['https://tangerinezest.com/wp-content/uploads...
#
#                                        recipeIngredient  \
# 2047  ['Farine - 250g', 'Oeufs - 1', 'Sucre - 100g',...
# 2233  ['Farine - 250g', 'Oeufs - 1', 'Sucre - 100g',...
# 2356  ['1/2 gousse vanille', '400 g crème de noix de...
# 4807  ['2  yaourts à la grecque', '2  kiwis', '8  pe...
# 6923  ['20 cl de lait (entier ou demi-écrémé)', '20 ...
# 7043  ['500 ml de lait', '60 g de sucre', '15 g de m...
#
#                                      recipeInstructions  recipeYield  \
# 2047  ['Préparation de la pâte sablée (pour la versi...  6 personnes
# 2233  ['Préparation de la pâte sablée (pour la versi...  6 personnes
# 2356  ['Mettez tous les ingrédients dans la casserol...       6 pots
# 4807  ['Émiettez et disposez au fond des ramequins l...            4
# 6923  ['Faites préchauffer votre four à 160°C.Versez...  4 personnes
# 7043  ['Dans une casserole, versez le lait et le suc...            6
#
#                                             author                  totalTime  \
# 2047  http://cuisinemoiunmouton.com/author/erossa/                        NaN
# 2233  http://cuisinemoiunmouton.com/author/erossa/                        NaN
# 2356                                    deliacious  0 days 00:15:00.000000000
# 4807                                       Valérie  0 days 00:05:00.000000000
# 6923                                           Léa                        NaN
# 7043                                           Léa                        NaN
#
#                   datePublished
# 2047                 2015-03-10
# 2233                 2015-03-10
# 2356  2019-02-18 17:19:20+00:00
# 4807  2014-05-26 11:14:32+00:00
# 6923  2019-02-20 04:23:18+00:00
# 7043  2017-04-03 16:58:40+00:00

# %%
#cuisineaddict[cuisineaddict['url'] == "https://cuisine-addict.com/pizza-healthy-chou-fleur-merzer/"]
# Out:
# Empty DataFrame
# Columns: [name, author, datePublished, image, recipeYield, recipeIngredient, recipeInstructions, url, prepTime, cookTime, totalTime]
# Index: []

# %%
emiliemurmure
# Out:
#                                                  image  \
# 0    ['http://emiliemurmure.com/wp-content/uploads/...
# 1    ['http://emiliemurmure.com/wp-content/uploads/...
# 2    ['http://emiliemurmure.com/wp-content/uploads/...
# 3    ['http://emiliemurmure.com/wp-content/uploads/...
# 4    ['http://emiliemurmure.com/wp-content/uploads/...
# ..                                                 ...
# 135  ['http://emiliemurmure.com/wp-content/uploads/...
# 136  ['http://emiliemurmure.com/wp-content/uploads/...
# 137  ['http://emiliemurmure.com/wp-content/uploads/...
# 138  ['http://emiliemurmure.com/wp-content/uploads/...
# 139  ['http://emiliemurmure.com/wp-content/uploads/...
#
#                                       recipeIngredient  \
# 0    ['Tofu fumé grillé ail et gingembre\xa0:', "un...
# 1    ['Mac and cheese:', '2 tasses de macaronis', '...
# 2    ['Bretzel au cheddar:', '1 ½ tasse d’eau tiède...
# 3    ['3 cuillères à soupe de beurre', "une cuillèr...
# 4    ['10 œufs', '¼ de tasse de fromage à la crème'...
# ..                                                 ...
# 135  ['- 250g de farine', '- 90g de beurre', '- 45g...
# 136  ['- une tasse (250g) de riz arborio', "- 3 tas...
# 137  ['- 2 tasses de farine non blanchie', "- 1 tas...
# 138  ['1/2 tasse de dattes hachées grossièrement', ...
# 139  ['- 75g / 100g de saumon fumé ou frais', '- un...
#
#                                                   name  \
# 0     One pot "sauté asiatique" au tofu fumé et sésame
# 1        Croquette de mac and cheese frites au cheddar
# 2                                   Bretzel au cheddar
# 3    Mini-pâté végétarien - protéine végétale, noix...
# 4    Oeuf mimosa ("deviled egg") au saumon, aneth e...
# ..                                                 ...
# 135  Tartelette aux agrumes, pamplemousse et orange...
# 136             Riz au lait d'amande, cardamome & coco
# 137  Muffins aux Poires & Thé vert Matcha avec crum...
# 138                         Barre de céréales Maison !
# 139                     Tartare de saumon croustillant
#
#                       cookTime                   prepTime  \
# 0    0 days 00:15:00.000000000  0 days 00:10:00.000000000
# 1    0 days 00:20:00.000000000  0 days 00:40:00.000000000
# 2    0 days 00:12:00.000000000  0 days 01:30:00.000000000
# 3    0 days 00:35:00.000000000  0 days 00:40:00.000000000
# 4    0 days 00:10:00.000000000  0 days 00:30:00.000000000
# ..                         ...                        ...
# 135                        NaN                        NaN
# 136                        NaN                        NaN
# 137                        NaN                        NaN
# 138                        NaN                        NaN
# 139                        NaN                        NaN
#
#                                     recipeInstructions    recipeYield  \
# 0    ["Couper le tofu en cube. Dans un wok, chauffe...              4
# 1    ['Cuire les macaronis dans un grand volume d’e...      20 boules
# 2    ['Dans un petit bol, verser l’eau tiède, le su...            NaN
# 3    ['Dans un grand bol, mélanger la farine et le ...  12 mini-pâtés
# 4    ["Cuire les œufs dans une grande quantité d'ea...  20 demi-oeufs
# ..                                                 ...            ...
# 135                                            ['nan']            NaN
# 136  ["Rincer le riz à l'eau.Dans une casserole, aj...            NaN
# 137  ["Préchauffer le four à 350°F / 180°C.Préparer...            NaN
# 138  ["Dans un robot, mixer les dattes en petits mo...            NaN
# 139  ["Couper le concombre en très petits dès.Coupe...            NaN
#
#                      totalTime  \
# 0    0 days 00:25:00.000000000
# 1    0 days 01:00:00.000000000
# 2    0 days 01:42:00.000000000
# 3    0 days 01:15:00.000000000
# 4    0 days 00:40:00.000000000
# ..                         ...
# 135                        NaN
# 136                        NaN
# 137                        NaN
# 138                        NaN
# 139                        NaN
#
#                                                    url        datePublished  \
# 0    http://emiliemurmure.com/one-pot-saute-asiatiq...                  NaN
# 1    http://emiliemurmure.com/croquettes-de-mac-and...                  NaN
# 2    http://emiliemurmure.com/bretzel-au-cheddar-et...                  NaN
# 3    http://emiliemurmure.com/mini-pate-vegetarien-...                  NaN
# 4    http://emiliemurmure.com/oeuf-mimosa-deviled-e...                  NaN
# ..                                                 ...                  ...
# 135  http://emiliemurmure.com/tartelettes-aux-agrum...  2014-02-22 17:37:27
# 136  http://emiliemurmure.com/riz-au-lait-damande-c...  2014-02-09 17:54:37
# 137  http://emiliemurmure.com/muffins-aux-poires-ma...  2014-02-01 19:55:01
# 138  http://emiliemurmure.com/barres-de-cereales-ma...  2014-09-04 17:24:00
# 139  http://emiliemurmure.com/tartare-de-saumon-cro...  2014-12-15 12:28:50
#
#     author
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 135    NaN
# 136    NaN
# 137    NaN
# 138    NaN
# 139    NaN
#
# [140 rows x 11 columns]
