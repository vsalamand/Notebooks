# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import spacy
from spacy.lang.fr import French
from spacy.tokenizer import Tokenizer
from spacy.tokens import Doc
from spacy.vocab import Vocab
from spacy.matcher import Matcher
from spacy.matcher import PhraseMatcher
from textblob import TextBlob
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import re
# Out:
# /anaconda3/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
measurements = {"g": ["gr.", "gr", "g", "g.", "gramme"], "kg": ["kg.", "kg", "kilogramme"], "mg": ["mg.", "mg", "miligramme"],
                "ml": ["ml.", "ml", "mililitre"], "cl": ["cl.", "cl", "centilitre"], "l": ["l.", "l", "litre"],
                "cuillère à soupe": ["c. à soupe", "cuillère à soupe", "cs", "cas", "càs", "c. à table", "cuillère à table"],
                "cuillère à café": ["c. à café", "cuillère à café", "cc", "cac", "càc", "c. à thé", "cuillère à thé"],
                "tasse": ["tasse"], "bol": ["bol"], "verre": ["verre"], "filet": ["filet"], "zeste": ["zeste"], "pièce": ["pièce"],
                "noisette": ["noisette"], "noix": ["noix"], "pincée": ["pincée"], "pointe":["pointe"], "poignée": ["poignée"],
                "feuille": ["feuille"], "branche": ["branche"], "gousse": ["gousse"], "tranche": ["tranche"], "cube": ["cube"],
                "boîte": ["boîte"], "barquette": ["barquette"], "pot": ["pot"], "bâtonnet": ["bâtonnet"], "boule": ["boule"],
                "rouleau": ["rouleau"], "p": ["p"]}

units = [item for sublist in measurements.values() for item in sublist]

quantities = { "½": 0.5, "1/2": 0.5, "1½": 1.5, "1 1/2": 0.5, "⅓": 0.33, "1/3": 0.33, "¼": 0.25, "1/5": 0.2, "¼": 0.25, "un demi": 0.5, "une demi": 0.5,"un et demi": 1.5,
              "tiers": 0.33, "quart": 0.25, "zero": 0, "deux": 2, "trois": 3, "quatre": 4,"cinq": 5, "six": 6, "sept": 7,
              "huit": 8, "neuf": 9, "dix": 10, "onze": 11, "douze": 12, "treize": 13, "quatorze": 14, "quinze": 15, "seize": 16,
              "dix-sept": 17, "dix-huit": 18, "dix-neuf": 19, "vingt": 20, "trente": 30, "quarante": 40, "cinquante": 50,
              "soixante": 60, "soixante-dix": 70, "quatre-vingt": 80, "quatre-vingt-dix": 90, "dizaine": 10, "une dizaine": 10,
              "douzaine": 12, "une douzaine": 12, "demi-douzaine": 6, "une demi-douzaine": 6, "vingtaine": 20, "une vingtaine": 20,
              "trentaine": 30, "quarantaine": 40, "cinquantaine": 50, "centaine": 100, "une centaine": 100, "cent": 100,
              "un": 1, "une": 1}

char_list = [i for i in "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZéèàâêïù▪️"]

# %%
web_product_data = pd.read_csv ('/Users/vincentsalamand/Downloads/products_leclerc.csv')
print(len(web_product_data))

data = pd.DataFrame()
data['quantity_match'] = ""
data['unit_match'] = ""
data['price_match'] = ""
data['price_per_unit_match'] = ""
data['is_promo'] = ""
data['offer'] = ""
data = pd.concat([data, web_product_data], axis=1)
data['shelter'] = ""
data['store'] = "Leclerc"
# Out:
# 6152

# %%
data['price_match'] = data.price.apply(lambda x: float(x.split()[0]))
data['price_per_unit_match'] = data.price_per_unit.apply(lambda x: float(x.split()[0]))
data.quantity_match = round(data.price_match / data.price_per_unit_match, 3)
#data['promo_price_per_unit_match'] = data.promo_price.apply(lambda x: float(re.sub("[^\d.]+", "", x)))

# Get names of indexes for which column price_per_unit_match is belo 0.03
missing_price_unit = data[data.price_per_unit_match < 0.03].index
# Delete these row indexes from dataFrame
data.drop(missing_price_unit , inplace=True)

# %%
# match description to find unit
nlp = French()

def convert_unit(value):
    results = []
    result = [unit for unit, item in measurements.items() if value in item]
    if len(result) > 0:
        return result[0]

measurement_matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
measurement_patterns = list(nlp.tokenizer.pipe(list(units)))
measurement_matcher.add("MEASUREMENT_PATTERN", None, *measurement_patterns)
tokenizer = Tokenizer(nlp.vocab)

measurement_parser = []
price_per_unit = list(nlp.pipe(data.price_per_unit))

for line in price_per_unit:
    line = tokenizer(re.sub('[0-9]', ' ', line.text))
    matches = measurement_matcher(line)
    elements = []
    if len(matches) > 0:
        for match_id, start, end in matches:
            span = line[start:end]
            elements.append(span.text.lower())
        measurement_parser.append(convert_unit(elements[0]))
    else:
        text_blob_object = TextBlob(line.text)
        singular_line = ' '.join(text_blob_object.words.singularize())
        matches = measurement_matcher(tokenizer(singular_line))
        if len(matches) > 0:
            for match_id, start, end in matches:
                span = tokenizer(singular_line)[start:end]
                elements.append(span.text.lower())
            measurement_parser.append(convert_unit(elements[0]))
        else:
            plural_line = ' '.join(text_blob_object.words.pluralize())
            matches = measurement_matcher(tokenizer(plural_line))
            if len(matches) > 0:
                for match_id, start, end in matches:
                    span = tokenizer(plural_line)[start:end]
                    elements.append(span.text.lower())
                measurement_parser.append(convert_unit(elements[0]))
            else:
                 measurement_parser.append("")

data['unit_match'] = measurement_parser

# %%
# Add ean & is_frozen column based on db_products + clean_description to avoid duplicate process later on
db_products = pd.read_csv('/Users/vincentsalamand/Downloads/product_export.csv')
db_store_items = pd.read_csv('/Users/vincentsalamand/Downloads/store_items_export.csv')

db_products_ean = db_products[['id', 'ean', 'is_frozen']]
db_store_items_ean = db_store_items.merge(db_products_ean, left_on=['product_id'], right_on=['id'])
db_store_items_ean = db_store_items_ean[['clean_name', 'store_product_id', 'ean', 'is_frozen']]

data = pd.merge(data, db_store_items_ean.rename(columns={'store_product_id':'product_id'}), on='product_id',  how='left')

# %%
# find if product is in promo
# rename piece unit
# get shelter list

for index, product in data.iterrows():
    if data.loc[index].offer_description == data.loc[index].price:
        data.loc[index,'is_promo'] = False
        data.loc[index,'offer_description'] = np.nan
    else:
        data.loc[index,'is_promo'] = True
    if data.loc[index].unit_match == "p":
        data.loc[index,'unit_match'] = "pièce"
    if data.loc[index].is_frozen == "f":
        data.loc[index,'is_frozen'] = False   
    if data.loc[index].is_frozen == "t":
        data.loc[index,'is_frozen'] = True         
    shelter = []
    shelter.append(data.loc[index].shelter_main)
    shelter.append(data.loc[index].shelter_parent)
    shelter.append(data.loc[index].shelter_child)
    data.at[index,'shelter'] = shelter

# %%
from selenium import webdriver
import requests
from bs4 import BeautifulSoup, CData
import html
from multiprocessing.dummy import Pool 

driver = webdriver.Chrome("/Applications/chromedriver")

def scrape_leclerc_product_pages(data):
    for index, product in data.iterrows():
        if pd.isna(data.iloc[index].ean):
            url = product.url
            print(url)
            driver.get(url)
            soup = BeautifulSoup(driver.page_source)
            product_info = []
            page = html.unescape(soup.text)
            page = page[(page.find('objProduit')-2):(page.find('objContenu')-2)]
            for line in page.split(","):
                if "fSurgele" in line:
                    data.loc[data.url == url].is_frozen = line[11:]
                if "sCodeEAN" in line:
                    data.loc[data.url == url].ean = line[12:-1]

scrape_leclerc_product_pages(data)
#p = Pool(10)
#p.map(scrape_leclerc_product_pages, data.url)
#p.terminate()
#p.join()
# Out:
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-85458-Steak-viande-Limousine.aspx
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-85459-Escalope-de-veau-Francais-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-31372-Agneau-souris-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-51382-Poitrine-tranchee-x7.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-85493-Pave-de-porc-Label-Rouge-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-84800-Saute-de-porc.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-26098-Steak-hache-Ferial.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-105193-Steack-Hache-LExquis-Ferial.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-105201-Steack-Hachee-Charal.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-87812-Steack-hache-pur-boeuf---12mg.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-110440-Viande-hachee-tradition-Charal.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-120801-Filets-de-poulet-OGM.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-120799-Filet-de-poulet-jaune-OGM.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-120800-Filet-de-poulet-blanc-Volandrie.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-120798-Filet-de-poulet-jaune-Volandrie.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-90665-Boulette-cuite-Nature-de-France.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-39453-Poulet-Le-Gaulois-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-107959-Cubes-poulet-blanc-Maitre-Coq.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115390-Aiguillettes-Le-Gaulois.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-107929-Tranches-de-dinde-Pere-Dodu.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-109399-Fine-escalope-de-dinde-noire.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-118289-Canard-confit-Marie.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-103515-Aiguillette-Maison-Montfort.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-90662-Nuggets-poulet-Nature-de-France.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-63971-Escalope-cordon-bleu-Pere-dodu.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-107763-Escalope-Le-Gaulois.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-48502-Poulet-en-box-Maitre-Coq.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-5273-Pilons-de-poulet-Cote-Croc.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-25748-Steaks-haches-Ronde-des-Mers.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-64169-Surimi-Petits-Coraya.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-59727-Surimi-Petits-Coraya-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-5817-Rillettes-de-saumon-Cap-ocean.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-78001-Ktipiti-Blini.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-32226-Tomate-cotelee.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-85048-Tomate-Cotelee-Noire-de-Crimee.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-110330-Tomate-ronde-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-55915-Poireau-Bio.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-2868-Legumes-pour-pot-au-feu.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-74284-Brocoli-Bio-Village.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-5947-Navet-Bio-filet-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-77509-Artichaut-Bio.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-84792-Carottes-Rapees-Bio-Bonduelle.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112847-Danao-Pocket-Peche-abricot-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112843-Boisson-lactee-Danao.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112846-Boisson-lactee-Danao.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-109451-Boisson-lactee-Danao.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-103131-Boisson-lactee-Danao.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-6113-Poires-Rochas.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-104898-Raisin-de-table-rose.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-102293-Pommes-Gala-Verger-La-Blottiere.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-102287-Pommes-Golden-La-Blottiere-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-26471-Pommes-Gala.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-8446-Pommes-Gala.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-95840-Orange-a-deguster-Bio-Village.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-95171-Orange-feuille.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-18524-Oranges-a-jus-filet.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-38706-Mandarine-Douceur-du-Verger.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-78399-Grenade-Wonderful.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-90895-Kiwi-Bio-Village.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-2525-Cerneaux-noix-Couleurs-Vives.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-109579-Pain-de-mie-Harrys-100-mie.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-39509-Pain-de-mie-Epi-dOr.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-3026-Canapes-toast-Harrys.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-6847-Canapes-toasts-Epi-dOr.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-5517-Canapes-toasts-Epi-dOr.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-100705-Tartine-Petit-dejeuner-Jacquet.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-50705-Toasts-ronds-nature-Jacquet.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-93181-Pains-Facon-Bretzel.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-93182-Pains-facon-Bretzel-Cereales-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-103158-Tartine-Grilletine-de-Pasquier.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-94752-Pains-au-chocolat-La-Boulangere.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-50689-Croissants-Pasquier.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-94751-Croissants-vegan-La-Boulangere.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-53777-Brioche-tressee-Pasquier-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-93181-Pains-Facon-Bretzel.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-93182-Pains-facon-Bretzel-Cereales-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-37480-Brioche-PitchPasquier.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-43918-Galette-des-rois-Pasquier.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-55220-Couronne-des-rois-Pasquier-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-40051-Crepes-bretonnes-Saint-Michel.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-92534-Madeleine-Cereal-Bio.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-12939-Lait-GrandLait-Bio-Candia.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-2613-Lait-Delisse-UHT-bouteille.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-69101-Lait-Bol-de-Vie-Lactel.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-2746-Lait-GrandLait-Candia-Bouteille.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-8745-Lait-GrandLait-Candia.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-8974-Lait-demi-ecreme-Viva-Candia.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-2760-Lait-demi-ecreme-Viva-Candia.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-6398-Lait-pasteurise-Bridel.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-6398-Lait-pasteurise-Bridel.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-12939-Lait-GrandLait-Bio-Candia.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-109451-Boisson-lactee-Danao.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-103131-Boisson-lactee-Danao.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112847-Danao-Pocket-Peche-abricot-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112846-Boisson-lactee-Danao.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112843-Boisson-lactee-Danao.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-66755-Boisson-a-la-noisette-Nat-Vie.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-45147-Boisson-coco-Bjorg-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115554-Beurre-Bio-Cest-qui-le-patron.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-77976-Beurre-AOC-Charentes-Poitou.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115637-Beurre-Bio-Cest-qui-le-patron.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-73842-Beurre-moule-Le-Gall-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112154-Margarine-allegee-Fruit-dOr.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112151-Margarine-allegee-Planta-Fin-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112159-Margarine-allegee-Fruit-dOr.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112155-Fruit-dOr-ProActive-Matiere.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-89912-Creme-Fraiche-Bio-Isigny-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-80976-Creme-fraiche-President.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-93466-Creme-entiere-Elle-Vire.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-109114-Fromage-Corsica-affine.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-119797-Comte-AOP-Les-Croises-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-119941-Tartare-ail-et-fines-herbes.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-33579-Fromage-Boursin.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-3640-Aperivrais-St-Moret.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-86757-Tranches-demmental-Bio-Village.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-77465-Rape-special-pizza-Les-Croises.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-108936-Comte-AOP-Entremont.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-82011-Pecorino-romano-rape-Galbani.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-40486-Pate-de-foie-forestier-Prunier.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-95541-Saucisse-courbe-Cochonou.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-41814-Cervelas-Herta.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-41754-Mortadelle-Bologna-IGP-Montorsi.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-88469-Blanc-de-poulet-Bio-Village.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-105136-Jambon-superieur-Tradilege.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-105137-Jambon-superieur-Tradilege.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112393-Jambon-superieur-etouffe-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-81820-Blanc-de-poulet-Le-Gaulois.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-81379-Jambon-Cru-Aoste.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-106614-Rosette-Justin-Bridou.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-75467-Pancetta-x10-Tranches.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-41818-Lardons-Herta.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-48202-Olives-farcies-Crocfrais.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-57432-Olives-aperitives.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-78001-Ktipiti-Blini.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-5817-Rillettes-de-saumon-Cap-ocean.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-63971-Escalope-cordon-bleu-Pere-dodu.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-107763-Escalope-Le-Gaulois.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-90662-Nuggets-poulet-Nature-de-France.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-48502-Poulet-en-box-Maitre-Coq.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-5273-Pilons-de-poulet-Cote-Croc.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-90665-Boulette-cuite-Nature-de-France.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-29781-Aligot-de-lAubrac.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-64983-Parmentier-de-boeuf.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-114000-Ravioli-Avec-Cepes-Rana.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-105224-Gnocchi-a-poeler-Lustucru-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-113655-Tarte-a-la-Savoyarde-Marie.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-51762-Tendre-croc-maxi-Herta.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-118465-Specialite-Perle-de-Lait.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-109394-Yaourts-bio-Les-2-vaches.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-7973-Faisselle-Rians.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-107166-Faisselle-Rians.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-62357-Faisselle-Rians.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-68790-Yaourt-laitier-Bio-Village.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-84470-Yaourts-Bio-Danone.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-108238-Yaourt-brasse-bio-Les-2-Vaches.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-82309-Yaourt-brasse-Bio-Les-2-vaches.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-108238-Yaourt-brasse-bio-Les-2-Vaches.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-70158-Yaourt-Panier-de-Yoplait.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-74774-Veloute-fruix-Danone.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-19965-Yaourts-Recette-cremeuse-Danone.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-113948-Yaourt-Yoplait.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-62357-Faisselle-Rians.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-110643-Yaourts-a-la-grecque-Delisse.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115872-Activia-yaourt-bifidus.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-19951-Specialite-laitiere-Taillefine.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-64101-Yaourts-Taillefine-0.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-100540-Yaourt-Bio-Les-2-Vaches.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-90888-Yaourt-Bio-Les-2-Vaches.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-91806-Yaourts-Danonino.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-109474-Yaourt-a-boire-Yop.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-109273-Yaourt-a-boire-Yop.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-109271-Yaourt-a-boire-Yoplait.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-119800-Petits-Filous-Go-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-64913-Yaourt-a-boire-Actimel-Danone.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-117160-Activia-Shot.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-118472-Specialite-Perle-de-Lait.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-118471-Specialite-Perle-de-Lait.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-118470-Specialite-Perle-de-Lait.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115910-Specialite-Laitiere-Vanille.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-110643-Yaourts-a-la-grecque-Delisse.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115905-Specialite-Laitiere-Coco.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115896-Specialite-laitiere-Nature.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-111829-Compote-Charles-Alice-sans-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115874-Dessert-fruitier-pomme-peche.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-69249-Dessert-fruitier-Andros.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-95872-Creme-dessert-Bio-Village.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-114643-Creme-dessert-Danette.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-113709-Creme-dessert-La-Laitiere-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-113808-Petit-pot-de-creme-La-Laitiere.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-113811-Petit-pot-de-creme-La-Laitiere.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-113813-Petit-pot-de-creme-La-Laitiere.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-941-Mousse-de-Viennois-Nestle.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-118967-Danette-Liegeois-chocolat.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-114662-Danette-Liegeois.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-114661-Danette-Liegeois.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-81850-Riz-au-lait-de-vache-Delisse.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-51079-Clafoutis-La-Laitiere.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-51249-Creme-brulee-La-laitiere.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-99587-Creme-dessert-au-soja-NatVie.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-58542-Specialite-au-soja-NatVie.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-117397-Dessert-vegetal-Coco-pommes.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-71511-Coquilles-St-Jacques-Cote-Table.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-33272-Mini-croustillants-Cote-Table.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-64637-Donuts-de-poulet-Maitre-Coq.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-71511-Coquilles-St-Jacques-Cote-Table.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-12789-Puree-nature-Mc-Cain.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-117405-Poelee-mediterraneenne-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-117407-Poelee-a-la-paysanne-Bonduelle.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-117404-Poelee-a-la-rustique-Bonduelle.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-117403-Poelee-de-legumes-Bonduelle.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-117406-Poelee-a-la-champetre-Bonduelle.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-114199-Potato-Pops.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-71535-Pommes-de-terre.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112761-Potatoes-Mc-Cain-Kid-Smile.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-103156-Frites-du-chnord-Pom-Bistrot.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115502-Persil-et-Ail-Rustica.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-63996-Glace-gourmande-Eskiss-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-44747-Glace-Mystere-Extreme-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-82176-Glace-Mystere-Extreme-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-10223-Framboises-entieres-Fruistar.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-75515-Lentilles-quinoa-legumes-Bio-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-75523-Hache-vegetal-Ail-Persil-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-104289-Quinoa-Ebly.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-114931-Riz-Uncle-Bens.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-91475-Riz-Comptoir-du-grain.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-114152-Pates-Bons-tuyaux-Jardin-Bio.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-8564-Pates-Linguine-Barilla.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-187-Pates-Fusilli-Barilla.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-8415-Pates-Coquillettes-Turini.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-48123-Pate-Radiatori-Garofalo.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115122-Spaghetti-Lustucru.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-90657-Riz-long-grain-Uncle-Bens.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-25770-Riz-Complet-Uncle-Bens.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-28928-Riz-Basmati-Uncle-Bens.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-28954-Riz-Risotto-Uncle-Bens.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-64927-Sauce-Bolognaise-Barilla.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-50102-Sauce-pate-olive-SaclaItalia.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-58461-Tapioca-Tipiak.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-90538-Coucous-Quinoa-Ebly.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-56571-Tomates-pelees-Bio-Village.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-3271-Mais-Notre-Jardin.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-15182-Filets-de-maquereaux-Saupiquet.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-83933-Filets-de-maquereaux-touche-de.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-82250-Thon-au-naturel-Petit-Navire.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-90057-Couscous-Jardin-Bio.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-103267-Paves-fondants-Cereal-Bio.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-79019-Galette-Boulghour-Cereal-Bio.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-79021-Galette-carree-Cereal-Bio.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-102464-Chips-banane-fruites-Ethiquable.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-6105-3Ds-Benenuts-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-68849-Mini-biscuits-Tokapi.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-101715-Petit-beurre-Michel-et-Augustin.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-118-Huile-Puget-olive.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-92842-Melange-4-huiles-Rustica.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-114156-Huile-vierge-coco-Jardin-Bio-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-11576-Vinaigre-balsamique-Jardin-Bio.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-104284-Bicarbonate-La-Baleine.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-71016-Poivre-noir-grain-Madagascar.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-37049-Sauce-Samourai-Amora.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-110000-Cornichons-croq-vert-Amora.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-49340-Cornichons-Eco.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-50109-Sauce-soja-Suzi-wan-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-110678-Bouillon-cube-Bio-Village.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-29202-Concentre-de-tomates-Giaguaro.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-73708-Puree-de-tomate-Eco.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-12724-Sauce-au-beurre-blanc-Rustica.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-20603-Sauce-a-lEchalote-Rustica.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-103564-Fleur-de-mais-Maizena.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112922-Veloute-de-legumes-verts-Liebig.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-68040-Veloute-PurSoup-Liebig.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-8027-Soupe-Veloute-Regal-Soupe.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-68935-Soupe-Regal-Soupe.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112908-Soupe-legumes-verts-Knorr.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112920-Soupe-8-legumes-Knorr.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112912-Soupe-legume-vert-Knorr.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-112911-Soupe-legume-lentille-Knorr.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-90804-Soupe-liquide-Knorr.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-90804-Soupe-liquide-Knorr.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-96722-Soupe-Courgette-Parmesan.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-12132-Sauce-soja-sucree-Suzi-Wan.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-50109-Sauce-soja-Suzi-wan-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-72752-Sauce-pour-nems-Suzi-Wan.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-48123-Pate-Radiatori-Garofalo.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-50102-Sauce-pate-olive-SaclaItalia.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115320-Capsules-aluminium-Plantation.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115332-Capsules-aluminium-Plantation.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115351-Capsules-aluminium-Plantation.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115321-Capsules-aluminium-Plantation.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115328-Capsules-aluminium-Plantation.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-63539-Dosettes-Carte-Noire.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-63536-Cafe-dosettes-Carte-Noire.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-63538-Cafe-dosettes-Carte-Noire.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-96270-Cafe-Lungo-Carte-Noire.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-19676-Cafe-Max-Havelaar-Malongo.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-396-Cafe-Lavazza-Mattino.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-8853-Cappuccino-soluble-Plantation.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-110090-Doypack-Banania.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-111464-The-vert-Bio-Pages.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-42455-The-vert-Lipton.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-111460-Infusion-ligne-Bio-Pages.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-111459-Infusion-nuit-Bio-Pages.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-100363-Tisane-Digestion-naturel-Yogi.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-78400-Infusion-Yogi.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-94054-Infusion-Bio-Yogi.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-65338-Infusion-detox-Yogi.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-78396-Infusion-Bio-Yogi-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-93828-Infusion-Yogi-relaxation.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-93831-Infusion-Bio-Yogi.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-78398-Infusion-Yogi.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-102890-Jordans-muesli-Choco.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115121-Muesli-sans-sucre-Kelloggs.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-104094-Cereales-extra-Kelloggs.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-97678-Country-crispy-3-baies.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-104863-Cereales-Bio-Lion-de-Nestle.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-104886-Cereales-Tresor-Kelloggs.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-101123-Cereales-Tresor-de-Kelloggs.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-91559-Cereales-Coco-Pops-Kelloggs.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-2965-Muesli-Country-Store-Kelloggs.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115120-Cereales-Fitness-Bio-Nestle.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115118-Cereales-Fitness-Bio-Nestle.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-32266-Cereales-Special-K-Kelloggs.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-94752-Pains-au-chocolat-La-Boulangere.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-50689-Croissants-Pasquier.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-94751-Croissants-vegan-La-Boulangere.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-53777-Brioche-tressee-Pasquier-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-115045-Brioche-tressee-Harrys.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-113680-Brioche-Harrys-Tressee-Nature.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-93181-Pains-Facon-Bretzel.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-93182-Pains-facon-Bretzel-Cereales-.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-109579-Pain-de-mie-Harrys-100-mie.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-39509-Pain-de-mie-Epi-dOr.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-116011-Biscotte-Pasquier.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-103158-Tartine-Grilletine-de-Pasquier.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-113110-Tartine-Grilletine-de-Pasquier.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-113108-Tartine-Grillettine-de-Pasquier.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-116584-Confiture-Bio-Village.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-7571-Confiture-Jardin-Bio.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-41174-Confiture-Les-Recettes-Cuites.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-47705-Pate-a-tartiner-Nocciolata.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-47704-Pate-a-tartiner-Nocciolata.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-81835-Pate-tartiner-Nocciolata.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-57110-Pate-a-tartiner-Nocciolata.aspx
# https://fd4-courses.leclercdrive.fr/magasin-127811-Bois-dArcy/fiche-produits-95051-Nocciolata-Bianca-Bio.aspx

# %%
data.head()
# Out:
#    quantity_match unit_match  price_match  price_per_unit_match  is_promo  \
# 0            0.16         kg         4.85                 30.31     False
# 1            0.28         kg         6.20                 22.14     False
# 2            0.16         kg         4.46                 27.88     False
# 3            0.24         kg         4.99                 20.79     False
# 4            0.26         kg         5.40                 20.77     False
#
#   offer      shelter_main shelter_parent  shelter_child  \
# 0   NaN  Viandes Poissons      Boucherie  Viande bovine
# 1   NaN  Viandes Poissons      Boucherie  Viande bovine
# 2   NaN  Viandes Poissons      Boucherie  Viande bovine
# 3   NaN  Viandes Poissons      Boucherie  Viande bovine
# 4   NaN  Viandes Poissons      Boucherie  Viande bovine
#
#                       description1             description2        brand  \
# 0  Viande bovine 1x faux filet ***     à griller Bio - 160g          NaN
# 1        Viande bovine 2x pavé ***     à griller Bio - 280g          NaN
# 2     Viande bovine Fr Bio Village        Faux filet - 160g  Bio Village
# 3         Viande bovine Bio vilage  Vbf - steak*** - 2x120g          NaN
# 4     Viande bovine Bio 2x steak**         A griller - 260g          NaN
#
#     price price_per_unit offer_description  origin  \
# 0  4.85 €   30.31 € / kg               NaN     NaN
# 1  6.20 €   22.14 € / kg               NaN     NaN
# 2  4.46 €   27.88 € / kg               NaN     NaN
# 3  4.99 €   20.79 € / kg               NaN     NaN
# 4  5.40 €   20.77 € / kg               NaN  France
#
#                                            image_url  \
# 0  https://fd4-photos.leclercdrive.fr/image.ashx?...
# 1  https://fd4-photos.leclercdrive.fr/image.ashx?...
# 2  https://fd4-photos.leclercdrive.fr/image.ashx?...
# 3  https://fd4-photos.leclercdrive.fr/image.ashx?...
# 4  https://fd4-photos.leclercdrive.fr/image.ashx?...
#
#                                                  url  product_id  \
# 0  https://fd4-courses.leclercdrive.fr/magasin-12...       54134
# 1  https://fd4-courses.leclercdrive.fr/magasin-12...       54136
# 2  https://fd4-courses.leclercdrive.fr/magasin-12...       53023
# 3  https://fd4-courses.leclercdrive.fr/magasin-12...       53022
# 4  https://fd4-courses.leclercdrive.fr/magasin-12...       16504
#
#                                         shelter    store  \
# 0  [Viandes Poissons, Boucherie, Viande bovine]  Leclerc
# 1  [Viandes Poissons, Boucherie, Viande bovine]  Leclerc
# 2  [Viandes Poissons, Boucherie, Viande bovine]  Leclerc
# 3  [Viandes Poissons, Boucherie, Viande bovine]  Leclerc
# 4  [Viandes Poissons, Boucherie, Viande bovine]  Leclerc
#
#                      clean_name            ean is_frozen
# 0       viande vin au filet île  3266110094989     False
# 1           viande vin pavé île  3266110097003     False
# 2  viande vin frisé la au filet  3661112098100     False
# 3           viande vin la steak  3661112098117     False
# 4  viande vin steak sarasin île  3266110093012     False

# %%
data["description"] = data.description1 + ' ' + data.description2

data.ean.fillna(0, inplace=True)
data.ean = data.ean.astype(int)
data = data.drop_duplicates(subset='ean', keep='first')

# %%
export_csv = data.to_csv (r'/Users/vincentsalamand/Downloads/leclerc_catalog.csv', index = None, header=True)

# %%
removed_items = db_store_items[~db_store_items.store_product_id.isin(data.product_id)]
len(removed_items)
#new_items = data[~data.product_id.isin(db_store_items.store_product_id)]
#len(new_items)
remaining_items = data[data.product_id.isin(db_store_items.store_product_id)]
len(remaining_items)
#df1[df1.product_id == 104789]
# Out:
# 5064

# %%
db_foods = pd.read_csv('/Users/vincentsalamand/Downloads/food_export.csv')

food_vocab = [food.split() for food in db_foods.name]
food_vocab_uniq = set([item for sublist in food_vocab for item in sublist])
food_vocab_uniq

for index, product in data.iterrows():
    # get clean name only if not already there
    if pd.isna(data.iloc[index].clean_name):
        description = ''.join(product.description)    
        clean_description = []
        for word in description.lower().split():
            ratio = process.extractOne(word, food_vocab_uniq)
            if ratio[1] > 88:
                clean_description.append(ratio[0])
        data.loc[index,'clean_name']  = ' '.join(clean_description)
# Out:
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ':']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '%']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '&']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ':']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '&']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '&']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
